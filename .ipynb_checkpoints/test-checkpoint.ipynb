# %%
# %run model-test.ipynb

# %%
x = torch.randn(16, 10)

m = Model()

y = m(x)
y.shape
# Out:
# torch.Size([16, 1])

# %%
for i in m.modules():
    print(type(i))
# Out:
# <class '__main__.Model'>
# <class 'torch.nn.modules.linear.Linear'>

# %% [markdown]
# Drawing

# %%
from PIL import Image, ImageDraw, ImageFont

WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
MAX_LENGTH = 5

def draw_1d_layer(draw, length, diameter, font, x_offset=0, y_offset=0):
    
    if length > MAX_LENGTH:
        for i in range(MAX_LENGTH):
            draw.ellipse([(x_offset, i*diameter + y_offset), (x_offset + diameter, (i+1)*diameter + y_offset)], outline=BLACK)
        draw.text((x_offset, MAX_LENGTH*diameter + y_offset), '...', align='left', fill=BLACK, font=font)
    else:
        for i in range(length):
            draw.ellipse([(x_offset, i*diameter + y_offset), (x_offset + diameter, (i+1)*diameter + y_offset)], outline=BLACK)
    
def draw_model(model, x):

    font = ImageFont.truetype("helvetica.ttf", 20)

    IMG_HEIGHT = 500
    IMG_WIDTH = 500
    NODE_DIAMETER = 40
    
    img = Image.new("RGB", (IMG_HEIGHT, IMG_WIDTH), WHITE) 
    
    draw = ImageDraw.Draw(img) 
    
    # Draw X
    
    draw.text((10, 10), f'X Input: {x.shape[1]}', align='center', fill=BLACK, font=font)
    draw_1d_layer(draw, x.shape[1], diameter=NODE_DIAMETER, font=font, x_offset=40, y_offset=40)

    
    display(img)

# %%
draw_model(m, x)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>
